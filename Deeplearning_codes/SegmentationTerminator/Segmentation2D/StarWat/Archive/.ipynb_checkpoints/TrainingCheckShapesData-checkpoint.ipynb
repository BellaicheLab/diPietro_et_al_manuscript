# %%
import os
import glob 
from tifffile import imread

ImageDirectorySimpl = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_StarWat/Training_Data_Movies_Segmentations/Boris_Data_TurdJoke_Images/_SeparatedMovies/BIG_1/Raw'
Raw_path = os.path.join(ImageDirectorySimpl, '*tif') #tif or TIF be careful
filesRaw = glob.glob(Raw_path)
filesRaw.sort

for fname in filesRaw:

        x = imread(fname)
  #      print(fname)
        print(x.shape)


print('passage aux label')
        
LabelDirectorySimpl = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_StarWat/Training_Data_Movies_Segmentations/Boris_Data_TurdJoke_Images/_SeparatedMovies/BIG_1/RealMask'     
Raw_path = os.path.join(LabelDirectorySimpl, '*tif') #tif or TIF be careful
filesRaw2 = glob.glob(Raw_path)
filesRaw2.sort

for fname in filesRaw2:

        x = imread(fname)
        #print(fname)
        print(x.shape)
# Out:
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# (1029, 2337)
# ...

# %%
import os
import glob 
from tifffile import imread

ImageDirectorySimpl = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_StarWat/Training_Data_Movies_Segmentations/Boris_Data_TurdJoke_Images/_SeparatedMovies/BIG_5/Raw'
Raw_path = os.path.join(ImageDirectorySimpl, '*tif') #tif or TIF be careful
filesRaw = glob.glob(Raw_path)
filesRaw.sort

for fname in filesRaw:

        x = imread(fname)
  #      print(fname)
        print(x.shape)


print('passage aux label')
        
LabelDirectorySimpl = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Training_Data_Sets/Training_StarWat/Training_Data_Movies_Segmentations/Boris_Data_TurdJoke_Images/_SeparatedMovies/BIG_5/RealMask'     
Raw_path = os.path.join(LabelDirectorySimpl, '*tif') #tif or TIF be careful
filesRaw2 = glob.glob(Raw_path)
filesRaw2.sort

for fname in filesRaw2:

        x = imread(fname)
        #print(fname)
        print(x.shape)
# Out:
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# (1154, 2358)
# ...
