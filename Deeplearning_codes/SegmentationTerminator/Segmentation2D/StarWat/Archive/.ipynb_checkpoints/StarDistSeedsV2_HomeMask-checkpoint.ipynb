# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import os
import cv2

#To run the prediction on the GPU, else comment out this line to use the CPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

from csbdeep.utils.tf import limit_gpu_memory
from skimage.filters import threshold_otsu
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.path.append('../../Terminator/')

from IPython.display import clear_output
import glob
from tifffile import imread
import tqdm
from csbdeep.utils import Path, normalize
from stardist import random_label_cmap, _draw_polygons,dist_to_coord
from stardist.models import StarDist2D
from TerminatorUtils.helpers import normalizeFloat, OtsuThreshold2D, save_8bit_tiff_imagej_compatible, save_16bit_tiff_imagej_compatible,Integer_to_border,SeedStarDistWatershed
from TerminatorUtils.helpers import Prob_to_Binary, zero_pad
from TerminatorUtils.helpers import save_tiff_imagej_compatible
from csbdeep.models import Config, CARE
np.random.seed(6)
lbl_cmap = random_label_cmap()

from skimage.morphology import remove_small_objects
from skimage.morphology import skeletonize


import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Movie 1 + model importation**

# %%
basedir = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a'

basedir_StardistWater_FijiMask = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/StarWat_FijiMask/'
basedir_StardistWater_FijiMask_RTGPipeline = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/StarWat_FijiMask_RTGPipeline/'

Model_Dir = '/home/sancere/NextonDisk_1/Lucas_Model_to_use/Segmentation/'

# %%
StardistModelName = 'DrosophilaSegmentationSmartSeedsMatureMacroMiniElongatedLargePatch'

modelstar = StarDist2D(config = None, name = StardistModelName, basedir = Model_Dir)
# Out:
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Loading network weights from 'weights_best.h5'.
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
Path(basedir_StardistWater_FijiMask).mkdir(exist_ok = True)
Raw_path = os.path.join(basedir, '*tif') #tif or TIF be careful
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw = glob.glob(Raw_path)
filesRaw.sort
# Out:
# <function list.sort>

# %%
for fname in filesRaw:
 
    if os.path.exists((basedir_StardistWater_FijiMask + 'StarWat_FijiMask_' + os.path.basename(os.path.splitext(fname)[0]))) == False :
        
            # Name = os.path.basename(os.path.splitext(fname)[0])
            x = imread(fname)
            y = normalizeFloat(x,1,99.8, axis = axis_norm)
            originalX = x.shape[0]
            originalY = x.shape[1]
        
            #zero pad aand 8bit conversion after normalization
            y = zero_pad(y, 32, 32)
            print('Processing file', fname)              
           
            #Stardist, label image, details, probability map, distance map 
            segmentationImage, details = modelstar.predict_instances(y)
            prob, dist = modelstar.predict(y)
            grid = modelstar.config.grid
            prob = cv2.resize(prob,  dsize=(prob.shape[1] * grid[1],prob.shape[0] * grid[0]))
            
            
            #Seeds from Stardist + Whatershed, segmentation on probability map 
            Watershed, markers = SeedStarDistWatershed(prob,details['points'],modelstar.config.grid) 
                                                                   
            
            #Convert Integer image to binary
            Binary_Watershed = Integer_to_border(Watershed[:originalX, :originalY])
                       
                                                       
            #Generation of masks                             
            HomeMadeMask = cv2.imread(fname.replace('.tif','_Mask.png'))
            HomeMadeMask = HomeMadeMask[:,:,0]
           
                                                                               
            #Create StardistWater_StardistMask and StardistWater_UnetMask with logical and operation            
            StardistWater_FijiMask = np.logical_and(HomeMadeMask, Binary_Watershed)
           
        
            #Skeletonization and deletion of non closed cells. Has to be done AFTER logical and operation 
            z = StardistWater_FijiMask 
            z = skeletonize(z) 
            z = np.float32(z)
            z2 = z.copy()
            mask = np.zeros((np.array(z.shape)+2), np.uint8)
            cv2.floodFill(z, mask, (0,0), (255))
            z = cv2.erode(z, np.ones((3,3)))
            z = cv2.bitwise_not(z)
            z = cv2.bitwise_and(z,z2)
            StardistWater_FijiMask = z 
    
            #Save different method segmentations
            save_8bit_tiff_imagej_compatible((basedir_StardistWater_FijiMask + 'StarWat_FijiMask_' + os.path.basename(os.path.splitext(fname)[0]) ) , StardistWater_FijiMask, axes)
# Out:
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0121.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0027.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0126.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0164.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0130.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0195.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0184.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0219.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0230.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0088.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0089.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0009.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0151.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0208.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0177.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0135.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0049.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0047.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0200.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0147.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0016.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0110.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0028.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0007.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0222.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0018.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0052.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0012.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0046.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0057.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0187.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0149.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0108.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0207.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0080.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0084.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0038.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0186.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0099.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0145.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0003.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0073.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0180.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0215.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0076.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0062.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0074.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0001.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0142.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0078.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0072.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0185.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0097.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0017.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0183.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0224.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0163.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0179.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0214.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0096.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0061.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0220.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0050.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0156.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0077.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0101.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0111.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0095.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0104.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0167.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0137.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0192.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0056.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0064.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0176.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0079.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0075.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0131.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0030.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0190.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0217.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0100.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0103.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0197.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0191.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0051.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0020.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0035.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0132.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0231.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0165.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0125.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0202.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0005.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0117.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0129.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0228.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0209.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0189.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0011.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0127.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0037.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0153.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0024.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0196.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0042.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0094.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0227.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0021.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0233.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0123.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0002.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0071.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0040.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0109.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0182.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0210.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0128.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0045.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0098.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0193.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0031.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0213.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0116.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0066.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0155.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0053.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0226.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0203.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0122.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0093.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0178.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0105.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0081.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0067.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0090.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0152.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0160.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0199.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0225.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0086.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0058.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0004.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0201.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0068.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0146.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0102.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0032.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0236.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0143.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0166.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0023.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0133.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0138.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0169.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0034.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0170.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0144.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0025.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0124.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0157.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0120.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0172.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0216.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0059.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0204.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0060.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0026.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0181.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0175.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0158.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0168.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0218.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0139.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0211.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0107.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0036.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0171.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0113.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0044.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0206.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0223.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0008.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0115.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0039.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0150.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0043.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0136.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0234.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0229.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0092.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0221.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0198.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0235.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0205.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0148.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0159.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0194.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0112.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0048.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0006.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0161.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0134.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0019.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0069.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0141.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0085.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0015.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0041.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0091.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0083.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0232.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0162.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0173.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0087.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0014.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0029.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0119.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0063.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0065.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0022.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0033.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0212.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0114.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0188.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0070.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0140.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0154.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0174.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0010.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0055.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0082.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0013.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0106.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0054.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/m_balakireva/Maria_Movie2Lucas/Pcna3a/PCNA_mov3a_cadCARE-3Gfp_Fused_0118.tif

# %%
from PIL import Image 
import png

Path(basedir_StardistWater_FijiMask_RTGPipeline).mkdir(exist_ok = True)

Raw_path_2 = os.path.join(basedir_StardistWater_FijiMask, '*') #tif or TIF be careful
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw_2 = glob.glob(Raw_path_2)
   
for fname in filesRaw_2:
    z = imread(fname)
    z = 255 * z
    z = cv2.bitwise_not(z)
    name = str(os.path.basename(os.path.splitext(fname)[0])).rstrip(".tif")
    png.from_array(z, mode="L").save(basedir_StardistWater_FijiMask_RTGPipeline + name.replace("StarWat_FijiMask_",'seg_') + '.png')

# %%
from matplotlib.pyplot import imread
from skimage import transform

Raw_path_3 = os.path.join(basedir_StardistWater_FijiMask_RTGPipeline, '*.png')
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw_3 = glob.glob(Raw_path_3)

xshift = -1
yshift = 1

translation = transform.AffineTransform(translation=(yshift,xshift))
    
for fname in filesRaw_3:
    img = imread(fname)
    img_translated = transform.warp(img, translation)
    img_translated = img_translated.astype('uint8')
    name = str(os.path.basename(os.path.splitext(fname)[0]))
    img_translated = 255 * img_translated
    png.from_array(img_translated, mode="L").save(basedir_StardistWater_FijiMask_RTGPipeline + '.png')
