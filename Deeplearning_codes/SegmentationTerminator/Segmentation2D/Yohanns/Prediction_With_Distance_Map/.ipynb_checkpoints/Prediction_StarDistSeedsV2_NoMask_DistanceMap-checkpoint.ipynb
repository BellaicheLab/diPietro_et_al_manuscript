# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import os
import cv2

#To run the prediction on the GPU, else comment out this line to use the CPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

from csbdeep.utils.tf import limit_gpu_memory
from skimage.filters import threshold_otsu
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.path.append('../../Terminator/')

from IPython.display import clear_output
import glob
from tifffile import imread
import tqdm
from csbdeep.utils import Path, normalize
from stardist import random_label_cmap, _draw_polygons,dist_to_coord
from stardist.models import StarDist2D
from TerminatorUtils.helpers import normalizeFloat, OtsuThreshold2D, save_8bit_tiff_imagej_compatible, save_16bit_tiff_imagej_compatible,Integer_to_border,SeedStarDistWatershed
from TerminatorUtils.helpers import Prob_to_Binary, zero_pad, WatershedwithMask, MaxProjectDist, WatershedSmartCorrection,fill_label_holes, WatershedwithoutMask
from TerminatorUtils.helpers import save_tiff_imagej_compatible
from csbdeep.models import Config, CARE
np.random.seed(6)
lbl_cmap = random_label_cmap()

from skimage.morphology import remove_small_objects, thin
from skimage.morphology import skeletonize


import time
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Movie 1 + model importation**

# %%
basedir = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8'

basedir_StardistWater_FijiMask = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/StarWat_Markers/'
basedir_StardistWater_FijiMask_RTGPipeline = '/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/StarWat_RTGPipeline/'

Model_Dir = '/run/media/sancere/DATA1/Lucas_Model_to_use/Segmentation/'

# %%
StardistModelName = 'DrosophilaSegmentationSmartSeedsMatureMacroMiniElongatedLargePatch'

modelstar = StarDist2D(config = None, name = StardistModelName, basedir = Model_Dir)
Model_is_for_Bin2 = False
# Out:
# Loading network weights from 'weights_best.h5'.
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.

# %%
Path(basedir_StardistWater_FijiMask).mkdir(exist_ok = True)
Raw_path = os.path.join(basedir, '*tif') #tif or TIF be careful
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw = glob.glob(Raw_path)
filesRaw.sort
# Out:
# <function list.sort>

# %%
for fname in filesRaw:
 
    if os.path.exists((basedir_StardistWater_FijiMask + 'StarWat_Markers' + os.path.basename(os.path.splitext(fname)[0]))) == False :
        
            # Name = os.path.basename(os.path.splitext(fname)[0])
            x = imread(fname)
            y = normalizeFloat(x,1,99.8, axis = axis_norm)
            originalX = x.shape[0]
            originalY = x.shape[1]
        
            #zero pad aand 8bit conversion after normalization
            y = zero_pad(y, 32, 32)
            print('Processing file', fname)              
           
            #Stardist, label image, details, probability map, distance map 
            segmentationImage, details = modelstar.predict_instances(y)
            segmentationImage = segmentationImage[:originalX, :originalY]
            prob, dist = modelstar.predict(y)
            grid = modelstar.config.grid
            prob = cv2.resize(prob,  dsize=(prob.shape[1] * grid[1],prob.shape[0] * grid[0]))
            dist = cv2.resize(dist, dsize=(dist.shape[1] * grid[1] , dist.shape[0] * grid[0] ))
            maxdist = MaxProjectDist(dist)  
            maxdist = maxdist[:originalX, :originalY]  

            
            #Generation of masks    
            #Seeds from Stardist + Whatershed, segmentation on probability map 
            HomeMadeMask = cv2.imread(fname.replace('.tif','_Mask.png'))
            HomeMadeMask = HomeMadeMask[:,:,0]
            HomeMadeMask = zero_pad(HomeMadeMask, 32, 32)
            HomeMadeMask = HomeMadeMask[:originalX, :originalY]
            Watershed, markers = WatershedwithoutMask(maxdist, segmentationImage.astype('uint16'),HomeMadeMask, modelstar.config.grid)
            Watershed = fill_label_holes(Watershed.astype('uint16'))

            
            #Convert Integer image to binary
            Binary_Watershed = Integer_to_border(Watershed[:originalX, :originalY])          
            StardistWater_FijiMask = Binary_Watershed
            
        
            #Skeletonization and deletionprint(image.shape)  of non closed cells. Has to be done AFTER logical and operation 
            z = StardistWater_FijiMask 
            z = skeletonize(z) 
            z = np.float32(z)
            z2 = z.copy()
            mask = np.zeros((np.array(z.shape)+2), np.uint8)
            cv2.floodFill(z, mask, (0,0), (255))
            z = cv2.erode(z, np.ones((3,3)))
            z = cv2.bitwise_not(z)
            z = cv2.bitwise_and(z,z2)
            StardistWater_FijiMask = z 
    
            #Save different method segmentations
            save_8bit_tiff_imagej_compatible((basedir_StardistWater_FijiMask + 'StarWat_FijiMask_' + os.path.basename(os.path.splitext(fname)[0]) ) , StardistWater_FijiMask, axes)
            # save_tiff_imagej_compati/run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8ble((basedir_StardistWater_FijiMask + 'DistMap_' + os.path.basename(os.path.splitext(fname)[0]) ) , maxdist, axes)
            save_tiff_imagej_compatible((basedir_StardistWater_FijiMask + 'Markers_' + os.path.basename(os.path.splitext(fname)[0]) ) , markers, axes)
# Out:
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0034.tif
# ../../Terminator/TerminatorUtils/helpers.py:583: UserWarning: Converting data type from 'float64' to ImageJ-compatible 'float32'.
#   warnings.warn("Converting data type from '%s' to ImageJ-compatible '%s'." % (t, np.dtype(t_new)))
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0144.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0169.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0008.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0147.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0083.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0172.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0158.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0175.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0035.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0142.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0108.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0145.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0011.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0098.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0015.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0033.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0029.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0006.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0020.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0110.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0128.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0085.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0060.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0087.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0146.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0081.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0018.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0170.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0129.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0075.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0068.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0088.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0116.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0023.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0058.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0055.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0173.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0082.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0135.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0012.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0013.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0030.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0163.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0136.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0150.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0017.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0106.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0105.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0041.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0114.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0154.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0162.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0121.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0101.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0021.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0054.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0131.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0038.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0153.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0076.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0093.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0016.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0176.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0061.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0005.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0113.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0022.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0066.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0094.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0036.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0063.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0165.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0102.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0155.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0148.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0103.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0064.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0096.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0045.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0149.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0126.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0070.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0080.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0077.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0048.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0062.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0109.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0024.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0168.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0164.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0117.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0069.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0059.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0039.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0047.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0104.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0115.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0152.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0084.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0003.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0052.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0078.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0092.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0056.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0134.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0119.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0027.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0100.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0111.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0123.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0073.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0177.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0130.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0095.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0002.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0127.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0159.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0053.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0132.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0074.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0086.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0051.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0057.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0091.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0122.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0099.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0174.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0140.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0120.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0137.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0141.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0009.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0026.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0037.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0019.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0049.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0151.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0167.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0007.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0028.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0072.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0118.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0042.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0067.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0133.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0044.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0160.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0156.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0125.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0032.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0139.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0161.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0025.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0124.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0001.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0112.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0079.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0065.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0143.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0171.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0010.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0050.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0040.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0031.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0004.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0138.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0071.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0107.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0043.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0046.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0089.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0090.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0097.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0014.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0157.tif
# Processing file /run/user/1000/gvfs/smb-share:server=isiserver.curie.net,share=u934/service_imagerie/v_kapoor/Lucas2Varun/wt_mov8/wt_mov8_DLcorr_0166.tif

# %%
from PIL import Image 
import png

Path(basedir_StardistWater_FijiMask_RTGPipeline).mkdir(exist_ok = True)

Raw_path_2 = os.path.join(basedir_StardistWater_FijiMask, '*') #tif or TIF be careful
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw_2 = glob.glob(Raw_path_2)
   
for fname in filesRaw_2:
    z = imread(fname)
    z = 255 * z
    z = cv2.bitwise_not(z)
    name = str(os.path.basename(os.path.splitext(fname)[0])).rstrip(".tif")
    png.from_array(z, mode="L").save(basedir_StardistWater_FijiMask_RTGPipeline + name.replace("StarWat_FijiMask_",'seg_') + '.png')

# %%
# No need to do the translation if segmentation bin2 model used
if Model_is_for_Bin2 == False:   

    from matplotlib.pyplot import imread
    from skimage import transform

    Raw_path_3 = os.path.join(basedir_StardistWater_FijiMask_RTGPipeline, '*.png')
    axis_norm = (0,1)   # normalize channels independently
    axes = 'XY'
    filesRaw_3 = glob.glob(Raw_path_3)

    xshift = -1
    yshift = 1

    translation = transform.AffineTransform(translation=(yshift,xshift))

    for fname in filesRaw_3:
        img = imread(fname)
        img_translated = transform.warp(img, translation)
        img_translated = img_translated.astype('uint8')
        name = str(os.path.basename(os.path.splitext(fname)[0]))
        img_translated = 255 * img_translated
        png.from_array(img_translated, mode="L").save(basedir_StardistWater_FijiMask_RTGPipeline + '.png')
