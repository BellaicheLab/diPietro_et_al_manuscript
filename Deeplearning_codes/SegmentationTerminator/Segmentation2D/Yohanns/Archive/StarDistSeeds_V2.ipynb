# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import os
import cv2

#To run the prediction on the GPU, else comment out this line to use the CPU
os.environ["CUDA_VISIBLE_DEVICES"]="1"

from csbdeep.utils.tf import limit_gpu_memory
from skimage.filters import threshold_otsu
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sys.path.append('../../Terminator/')

from IPython.display import clear_output
import glob
from tifffile import imread
import tqdm
from csbdeep.utils import Path, normalize
from stardist import random_label_cmap, _draw_polygons,dist_to_coord
from stardist.models import StarDist2D
from TerminatorUtils.helpers import normalizeFloat, OtsuThreshold2D, save_8bit_tiff_imagej_compatible, save_16bit_tiff_imagej_compatible,Integer_to_border,SeedStarDistWatershed
from TerminatorUtils.helpers import Prob_to_Binary, zero_pad
from TerminatorUtils.helpers import save_tiff_imagej_compatible
from csbdeep.models import Config, CARE
np.random.seed(6)
lbl_cmap = random_label_cmap()

from skimage.morphology import remove_small_objects
from skimage.morphology import skeletonize


import time
# Out:
# Using TensorFlow backend.

# %%
basedir = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a'

basedir_StardistWater_StardistMask = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/StarWat_StarMask/'
basedir_StardistWater_StardistMask_RTGPipeline = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/CycE04/StardistWater_StardistMask_RTGPipeline/'
basedir_StardistWater_UnetMask = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/StarWat_UnetMask/'
basedir_StardistMask = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/StarMask/'
basedir_UnetMask = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/UnetMask/'

Model_Dir = '/media/sancere/Newton_Volume_1/CurieDeepLearningModels/DrosophilaSegmentation'

# %%
StardistModelName = 'DrosophilaSegmentationSmartSeedsMatureMacroElongatedBoris'
UnetMaskModelName = 'DrosophilaMaskSegmentationCARE'

modelstar = StarDist2D(config = None, name = StardistModelName, basedir = Model_Dir)
modelmask = CARE(config = None, name = UnetMaskModelName, basedir = Model_Dir)
# Out:
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Loading network weights from 'weights_best.h5'.
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/sancere/anaconda3/envs/tensorflowGPU/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Couldn't load thresholds from 'thresholds.json', using default values. (Call 'optimize_thresholds' to change that.)
# Using default values: prob_thresh=0.5, nms_thresh=0.4.
# Loading network weights from 'weights_best.h5'.

# %%
# Path(basedir_StardistWater_StardistMask).mkdir(exist_ok = True)
Path(basedir_StardistWater_UnetMask).mkdir(exist_ok = True)
# Path(basedir_StardistMask).mkdir(exist_ok = True)
# Path(basedir_UnetMask).mkdir(exist_ok = True)

Raw_path = os.path.join(basedir, '*tif') #tif or TIF be careful

axis_norm = (0,1)   # normalize channels independently
axes = 'XY'

filesRaw = glob.glob(Raw_path)
# filesRaw.sort

# %%
for fname in filesRaw:
 
    if os.path.exists((basedir_StardistWater_UnetMask + 'StarWat_UnetMask_' + os.path.basename(os.path.splitext(fname)[0]))) == False :
#     if os.path.exists(basedir_StardistWater_StardistMask + 'StarWat_StarMask_' + os.path.basename(os.path.splitext(fname)[0])) == False \
#     or os.path.exists((basedir_StardistMask + 'StarMask_' + os.path.basename(os.path.splitext(fname)[0]))) == False \
#     or os.path.exists((basedir_UnetMask + 'UnetMask_' + os.path.basename(os.path.splitext(fname)[0]))) == False :
                     
            # Name = os.path.basename(os.path.splitext(fname)[0])
            x = imread(fname)
            y = normalizeFloat(x,1,99.8, axis = axis_norm)
            originalX = x.shape[0]
            originalY = x.shape[1]
        
            #zero pad aand 8bit conversion after normalization
            y = zero_pad(y, 32, 32)
            print('Processing file', fname)              
           
            #Stardist, label image, details, probability map, distance map 
            segmentationImage, details = modelstar.predict_instances(y)
            prob, dist = modelstar.predict(y)
            grid = modelstar.config.grid
            prob = cv2.resize(prob,  dsize=(prob.shape[1] * grid[1],prob.shape[0] * grid[0]))
            
            
            #Seeds from Stardist + Whatershed, segmentation on probability map 
            Watershed, markers = SeedStarDistWatershed(prob,details['points'],modelstar.config.grid) 
                                                                   
            StardistWater_UnetMask
            #Convert Integer image to binary
            Binary_Watershed = Integer_to_border(Watershed[:originalX, :originalY])
                       
                                                       
            #Generation of masks               
#             StardistMask = Prob_to_Binary(prob[:originalX, :originalY], segmentationImage[:originalX, :originalY])
              
            HomeMadeMask = cv2.imread(fname.replace('.tif','_Mask.png'))
            HomeMadeMask = HomeMadeMask[:,:,0]
            UnetMask = HomeMadeMask
            
#             UnetMask = modelmask.predict(x, axes, n_tiles = (1, 2))
#             UnetMask = UnetMask.astype('uint8')
#             thresh = threshold_otsu(UnetMask)
#             UnetMask = UnetMask > thresh*0.1
#             UnetMask = remove_small_objects(UnetMask, 5000)
#             UnetMask = UnetMask.astype('uint8')
            
                                                                   
            #Create StardistWater_StardistMask and StardistWater_UnetMask with logical and operation            
#             StardistWater_StardistMask = np.logical_and(StardistMask, Binary_Watershed)
            StardistWater_UnetMask = np.logical_and(UnetMask, Binary_Watershed)
           
        
            #Skeletonization and deletion of non closed cells (only for StardistWater_StardistMask here)
            z = StardistWater_UnetMask 
            z = skeletonize(z) 
            z = np.float32(z)
            z2 = z.copy()
            mask = np.zeros((np.array(z.shape)+2), np.uint8)
            cv2.floodFill(z, mask, (0,0), (255))
            z = cv2.erode(z, np.ones((3,3)))
            z = cv2.bitwise_not(z)
            z = cv2.bitwise_and(z,z2)
            StardistWater_UnetMask = z 
    
            #Save different method segmentations
#             save_8bit_tiff_imagej_compatible((basedir_StardistWater_StardistMask + 'StarWat_StarMask_' + os.path.basename(os.path.splitext(fname)[0])) ,  StardistWater_StardistMask, axes)
            save_8bit_tiff_imagej_compatible((basedir_StardistWater_UnetMask + 'StarWat_UnetMask_' + os.path.basename(os.path.splitext(fname)[0]) ) , StardistWater_UnetMask, axes)
#             save_8bit_tiff_imagej_compatible((basedir_StardistMask + 'StarMask_' + os.path.basename(os.path.splitext(fname)[0])) , StardistMask, axes)
#             save_8bit_tiff_imagej_compatible((basedir_UnetMask + 'UnetMask_' + os.path.basename(os.path.splitext(fname)[0]) ) , UnetMask, axes)
# Out:
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0186.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0009.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0157.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0212.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0100.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0034.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0191.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0079.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0259.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0271.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0148.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0209.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0264.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0064.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0116.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0127.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0269.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0201.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0229.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0230.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0239.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0112.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0279.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0281.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0260.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0093.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0125.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0169.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0242.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0011.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0240.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0017.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0274.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0267.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0031.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0262.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0227.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0068.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0210.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0074.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0062.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0069.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0268.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0139.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0223.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0183.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0107.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0196.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0207.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0137.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0144.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0222.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0179.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0234.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0216.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0190.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0006.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0046.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0027.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0094.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0121.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0098.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0008.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0081.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0015.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0145.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0038.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0162.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0060.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0245.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0023.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0193.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0029.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0051.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0228.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0165.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0080.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0018.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0198.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0010.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0217.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0142.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0151.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0141.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0055.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0175.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0220.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0131.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0043.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0173.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0232.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0120.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0224.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0181.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0035.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0280.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0106.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0203.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0176.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0273.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0205.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0160.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0256.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0082.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0003.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0039.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0102.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0066.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0085.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0140.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0132.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0158.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0119.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0199.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0177.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0180.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0134.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0189.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0103.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0254.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0195.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0130.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0143.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0088.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0105.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0136.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0247.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0258.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0028.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0159.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0194.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0243.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0084.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0016.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0213.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0161.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0096.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0153.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0204.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0166.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0133.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0037.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0184.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0146.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0111.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0266.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0032.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0272.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0075.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0050.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0156.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0117.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0042.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0126.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0263.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0278.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0090.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0097.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0197.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0236.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0147.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0095.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0076.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0065.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0078.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0238.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0052.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0252.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0182.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0192.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0036.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0070.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0020.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0071.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0277.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0261.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0002.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0270.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0044.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0099.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0047.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0110.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0211.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0237.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0135.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0057.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0185.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0244.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0104.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0073.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0170.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0077.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0174.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0113.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0129.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0012.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0001.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0150.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0109.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0122.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0215.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0056.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0250.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0163.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0033.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0219.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0171.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0013.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0053.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0257.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0200.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0188.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0164.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0041.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0061.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0253.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0208.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0248.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0101.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0086.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0019.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0045.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0005.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0251.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0054.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0124.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0007.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0072.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0030.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0155.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0172.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0087.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0108.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0022.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0178.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0226.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0114.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0154.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0221.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0092.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0241.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0128.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0040.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0246.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0275.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0091.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0206.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0049.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0168.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0004.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0063.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0138.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0083.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0214.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0187.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0021.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0025.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0059.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0024.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0089.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0058.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0231.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0225.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0167.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0123.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0149.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0235.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0048.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0014.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0265.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0276.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0067.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0115.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0152.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0118.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0249.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0233.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0255.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0218.tif
# Processing file /run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/vi2a_0026.tif

# %%
from PIL import Image 
import png


basedir_StardistWater_UnetMask_RTGPipeline = '/run/user/1001/gvfs/smb-share:server=isiserver.curie.net,share=u934/equipe_bellaiche/l_sancere/Maria_movies/vi2a/StardistWater_UnetMask_RTGPipeline/'
Path(basedir_StardistWater_UnetMask_RTGPipeline).mkdir(exist_ok = True)

Raw_path_2 = os.path.join(basedir_StardistWater_UnetMask, '*') #tif or TIF be careful
axis_norm = (0,1)   # normalize channels independently
axes = 'XY'
filesRaw_2 = glob.glob(Raw_path_2)


name_of_file = "Lucas Reminder Format"
completeName = os.path.join(basedir_StardistWater_UnetMask_RTGPipeline, name_of_file + ".txt")         
file = open(completeName, "w")
file.write("If Matlab Pipeline error appears it might be the format '8bit-color'. Can't be generated by python. Run the Pipeline from Cleaning Filter. Email Stephane for LOCALISATION in Pipeline")
file.close()


    
for fname in filesRaw_2:
    z = imread(fname)
    z = 255 * z
    z = cv2.bitwise_not(z)
    name = str(os.path.basename(os.path.splitext(fname)[0])).rstrip(".tif")
    png.from_array(z, mode="L").save(basedir_StardistWater_UnetMask_RTGPipeline + name.replace("StarWat_UnetMask",'seg_') + '.png')
