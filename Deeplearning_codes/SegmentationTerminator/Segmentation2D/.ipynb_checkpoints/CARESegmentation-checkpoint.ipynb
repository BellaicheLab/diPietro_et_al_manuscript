# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history

from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
# Out:
# Using TensorFlow backend.

# %%
BaseDir = '/data/u934/service_imagerie/v_kapoor/CurieTrainingDatasets/DrosophilaBinarySegmentation/'
NPZdata = 'UNetDrosSegmentModel'+ '.npz'

ModelDir ='/data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaSegmentation/'
ModelName = 'DrosophilaSegmentationUNet'
load_path = BaseDir + NPZdata

# %%
(X,Y), (X_val,Y_val), axes = load_training_data(load_path, validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 83405
# number of validation images:	 9267
# image size (2D):		 (256, 256)
# axes:				 SYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %%
config = Config(axes, n_channel_in, n_channel_out, probabilistic = False, unet_n_depth=5,unet_kern_size=3,train_epochs= 200, train_batch_size = 64, train_reduce_lr={'patience': 5, 'factor': 0.5})
print(config)
vars(config)
# Out:
# Config(axes='YXC', n_channel_in=1, n_channel_out=1, n_dim=2, probabilistic=False, train_batch_size=64, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_epochs=200, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'factor': 0.5, 'patience': 5}, train_steps_per_epoch=400, train_tensorboard=True, unet_input_shape=(None, None, 1), unet_kern_size=3, unet_last_activation='linear', unet_n_depth=5, unet_n_first=32, unet_residual=True)
# {'axes': 'YXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'n_dim': 2,
#  'probabilistic': False,
#  'train_batch_size': 64,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_epochs': 200,
#  'train_learning_rate': 0.0004,
#  'train_loss': 'mae',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 5},
#  'train_steps_per_epoch': 400,
#  'train_tensorboard': True,
# ...

# %%
model = CARE(config = config, name = ModelName, basedir = ModelDir)
model.load_weights(ModelDir + ModelName + '/' + 'weights_best.h5')
# Out:
# /data/u934/service_imagerie/v_kapoor/anaconda2/envs/tensorflowEXP/lib/python3.5/site-packages/csbdeep/models/base_model.py:134: UserWarning: output path for model already exists, files may be overwritten: /data/u934/service_imagerie/v_kapoor/CurieDeepLearningModels/DrosophilaSegmentation/DrosophilaSegmentationUNet
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# Epoch 1/200
# 400/400 [==============================] - 1004s 3s/step - loss: 0.0926 - mse: 0.0841 - mae: 0.0926 - val_loss: 0.0948 - val_mse: 0.0827 - val_mae: 0.0948
# Epoch 2/200
# 400/400 [==============================] - 989s 2s/step - loss: 0.0884 - mse: 0.0741 - mae: 0.0884 - val_loss: 0.0753 - val_mse: 0.0514 - val_mae: 0.0753
# Epoch 3/200
# 400/400 [==============================] - 988s 2s/step - loss: 0.0679 - mse: 0.0457 - mae: 0.0679 - val_loss: 0.0638 - val_mse: 0.0431 - val_mae: 0.0638
# Epoch 4/200
# 400/400 [==============================] - 990s 2s/step - loss: 0.0592 - mse: 0.0391 - mae: 0.0592 - val_loss: 0.0574 - val_mse: 0.0381 - val_mae: 0.0574
# Epoch 5/200
# 400/400 [==============================] - 988s 2s/step - loss: 0.0552 - mse: 0.0363 - mae: 0.0552 - val_loss: 0.0546 - val_mse: 0.0372 - val_mae: 0.0546
# Epoch 6/200
# ...

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %%
model.export_TF()
